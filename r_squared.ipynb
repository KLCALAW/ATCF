# %%
import pandas as pd

# %%
# Load the dataset
proxy_time_series_df_alex = pd.read_csv('data/proxy_time_series_alex.csv')

# Define a function to calculate R-squared
def calculate_r_squared(actual, predicted):
    ssr = ((actual - predicted) ** 2).sum()  # Sum of Squared Residuals
    tss = ((actual - actual.mean()) ** 2).sum()  # Total Sum of Squares
    return 1 - (ssr / tss)

# Calculate R^2 for a specific date
def r_squared_for_date(data, date, actual_col, predicted_col):
    date_data = data[data['Date'] == date]
    if not date_data.empty:
        actual = date_data[actual_col]
        predicted = date_data[predicted_col]
        return calculate_r_squared(actual, predicted)
    else:
        raise ValueError(f"No data found for the specified date: {date}")

# Calculate R^2 for the entire dataset
def r_squared_for_dataset(data, actual_col, predicted_col):
    actual = data[actual_col]
    predicted = data[predicted_col]
    return calculate_r_squared(actual, predicted)

# Calculate R^2 for a specific ticker and method
def calculate_r2_for_ticker(data, ticker, actual_col, predicted_col):
    # Filter the data for the specified ticker
    ticker_data = data[data["Ticker"] == ticker]
    if ticker_data.empty:
        raise ValueError(f"No data found for the specified ticker: {ticker}")
    
    # Calculate R^2
    r2 = calculate_r_squared(ticker_data[actual_col], ticker_data[predicted_col])
    return r2

# %%
# Specify columns for actual and predicted spreads
actual_col = "Actual_Spread"
predicted_col = "Proxy_Intersection"


specific_date = '2010-09-15' 
r2_specific_date = r_squared_for_date(proxy_time_series_df_alex, specific_date, actual_col, predicted_col)
print(f"R^2 CSRA for {specific_date}: {r2_specific_date}")


r2_entire_dataset = r_squared_for_dataset(proxy_time_series_df_alex, actual_col, predicted_col)
print(f"R^2 CSRA for the entire dataset: {r2_entire_dataset}")

# Compare to CSRA_Community
predicted_col = "Proxy_CSRA_Community"
 
r2_specific_date = r_squared_for_date(proxy_time_series_df_alex, specific_date, actual_col, predicted_col)
print(f"R^2 CSRA_Community for {specific_date}: {r2_specific_date}")


r2_entire_dataset = r_squared_for_dataset(proxy_time_series_df_alex, actual_col, predicted_col)
print(f"R^2 CSRA_Community for the entire dataset: {r2_entire_dataset}")
# Out:
# R^2 CSRA for 2010-09-15: -0.131787502095023
# R^2 CSRA for the entire dataset: -0.054790981187530896
# R^2 CSRA_Community for 2010-09-15: -0.2640007033215077
# R^2 CSRA_Community for the entire dataset: -1.9054669834930165

# %%
ticker = "AAUK"  
actual_col = "Actual_Spread"  
predicted_col = "Proxy_CSRA"  # Replace with your desired proxy method (e.g., "Proxy_CSRA" or "Proxy_CSRA_Community")

r2_ticker = calculate_r2_for_ticker(proxy_time_series_df_alex, ticker, actual_col, predicted_col)
print(f"R^2 for {ticker} ({predicted_col}): {r2_ticker}")
# Out:
# R^2 for AAUK (Proxy_CSRA): -3.3918826854063227

# %%
# Loop over all tickers to calculate R^2
def calculate_r2_for_all_tickers(data, actual_col, predicted_col):
    ticker_r2_results = {}
    unique_tickers = data["Ticker"].unique()  # Get all unique tickers

    for ticker in unique_tickers:
        try:
            # Filter data for each ticker and calculate R^2
            ticker_data = data[data["Ticker"] == ticker]
            r2 = calculate_r_squared(ticker_data[actual_col], ticker_data[predicted_col])
            ticker_r2_results[ticker] = r2  # Store the result
        except Exception as e:
            print(f"Error calculating R^2 for ticker {ticker}: {e}")
            ticker_r2_results[ticker] = None  # Store None if there's an error

    return ticker_r2_results

# Specify the columns
actual_col = "Actual_Spread"  
predicted_col = "Proxy_Intersection"  # Replace with your desired proxy method (e.g., "Proxy_CSRA" or "Proxy_CSRA_Community")

# Calculate R^2 for all tickers
r2_results = calculate_r2_for_all_tickers(proxy_time_series_df_alex, actual_col, predicted_col)

# Display the results
for ticker, r2 in r2_results.items():
    print(f"R^2 for {ticker}: {r2}")
# Out:
# R^2 for AAUK: -0.5320478845059791
# R^2 for ABE: -3.659662570565895
# R^2 for ABHLTD: -1.0930331717795418
# R^2 for ACAFP: 0.46342624595744586
# R^2 for ACAFP-CIB: -5.484440979297272
# R^2 for ACCOR: -0.8350824582429979
# R^2 for ACEA: -337.9886840970632
# R^2 for ADIG: -28.14384111925619
# R^2 for AEGON: 0.6303897403136484
# R^2 for AF: -3.832322131202476
# R^2 for AF-AirFrance: -3.7680731256001145
# R^2 for AGASSA: -1.0227860385655858
# R^2 for AGS: -22.028368024599718
# R^2 for AGS-Intl: -224.49366350665767
# R^2 for AIRLIQ: -34.639122430666006
# R^2 for AKZO: -0.09875602850682519
# R^2 for AKZO-ICILD: -1686.9428278627058
# R^2 for ALCLCT: -3.28703587816549
# R^2 for ALINDR: -96.35306587496324
# R^2 for ALPHBK: -5.537245527686435
# R^2 for ALSTOM: -1.0171671880194886
# R^2 for ALT: -108.15221160984966
# R^2 for ALYD: -118.58135356654746
# R^2 for ALZSE: -0.7269735199804246
# R^2 for AMROBK: 0.7467415707382156
# R^2 for ANGLIA: 0.2576816468145303
# R^2 for ARMLL: -3.6156132716860174
# R^2 for ARMLL-FRA: -4.362723104590749
# R^2 for ARMLL-Fin: -62.62155947682527
# R^2 for ASSAAB: -39.41375644493245
# R^2 for ASSGEN: 0.8970300906935336
# R^2 for ATCOA: -106.82477361458449
# R^2 for ATSPA: -0.5208234076870895
# R^2 for AUST: -1.8853529097945927
# R^2 for AVLN: -1.7658246563969504
# R^2 for AWLN-AngWatServ: -1.4343481027769225
# R^2 for AXAF: -3.640089098863408
# R^2 for AYLL: -12.071902895593812
# R^2 for AZN: -129.84580800300972
# R^2 for BAB: -5.195112945921948
# R^2 for BACR-Bank: 0.6441573619844201
# R^2 for BACRED: 0.8794099993128827
# R^2 for BAD: -2.2001572309831725
# R^2 for BANSAB: -0.13339135254283696
# R^2 for BAPLC: 0.7971322781701727
# R^2 for BASFSE: 0.8451873567380637
# R^2 for BATSLN: -199.0466920418141
# R^2 for BBVSM: 0.9477290240184282
# R^2 for BCPN: -3.0997319316129994
# R^2 for BELG: 0.42522136631494456
# R^2 for BFCM: 0.9349175362402371
# R^2 for BKIR: -0.3371522134450573
# R^2 for BKTSM: -3.117908230484847
# R^2 for BMW: 0.8774281048495888
# R^2 for BNCBPI: 0.873996138950871
# R^2 for BNP: 0.9402197135758327
# R^2 for BOCGP: -27679.87249438216
# R^2 for BOUY: 0.4759592184595296
# R^2 for BPBL: -199.1432196056163
# R^2 for BPLN: -0.5222558002628197
# R^2 for BRISA: -3.321197246864874
# R^2 for BRITEL-BritTel: -2.1223086677747194
# R^2 for BRITLD: -2.6383674465665057
# R^2 for BRYBDC: -0.7173860074199205
# R^2 for BRYBDC-Brew: -0.7487186652884448
# R^2 for BSFSHW: -6178.699722275824
# R^2 for BWGPSK: -2.1736175398140887
# R^2 for BYIF: -42.64419762278898
# R^2 for BYLAN: 0.4646580542731502
# R^2 for CAJAME: 0.5042078393663038
# R^2 for CARR: 0.5844157950108246
# R^2 for CAWILD: -5.751528845484233
# R^2 for CCBP-NATIXI: 0.6452329250836922
# R^2 for CCLL: 0.1900200075464874
# R^2 for CENTRI: -15.791916008108181
# R^2 for CIRINT: -7.6812481938627375
# R^2 for CLAR: 0.2777086181381322
# R^2 for CMFP: -12.353402248434575
# R^2 for CMZB: 0.4183057050710388
# R^2 for CONTI: -1.6849687717043222
# R^2 for CPGLN: -39.90395333959883
# R^2 for CSGAG: -1.5364638531909023
# R^2 for CTSGL: -53.69387911651301
# R^2 for CXGD: 0.8493730853483332
# R^2 for CYPRUS: -2.968611288616109
# R^2 for DAA: 0.2701471836758693
# R^2 for DAMLR: -4.000430901749362
# R^2 for DANBNK: 0.15558069623104653
# R^2 for DANONE: -283.94423996792136
# R^2 for DB: 0.2237732609434433
# R^2 for DBB: -50.28633368026933
# R^2 for DBR: -30.633086264807293
# R^2 for DENK: -1.5992959649237402
# R^2 for DEPFA-Bank: -31.29462800349379
# R^2 for DEXGRP-CredLoc: -0.45637733216230836
# R^2 for DEXO: -150.69587980552285
# R^2 for DFHH: -69.22244741569604
# R^2 for DIAG: -19.603284141831825
# R^2 for DMGOLN: -49.392627528271845
# R^2 for DPW: -8.529283051191761
# R^2 for DT: -2.8011685737535292
# R^2 for DZBK: -8.40423775191473
# R^2 for EDF: 0.20508816688241926
# R^2 for EDP: -2.4430091159600074
# R^2 for EDP-FinBV: -1.9366090169704737
# R^2 for ELEBEL: -7.873771131138469
# R^2 for ELESM: 0.5254979941147745
# R^2 for ELIA: -33.03373942987113
# R^2 for ELIAC: -39.00031968130158
# R^2 for ELTLX: 0.6220368312120381
# R^2 for EMIG: -0.33603469185748835
# R^2 for ENDP: -4.396487590845907
# R^2 for ENEL: -2.1198781256690507
# R^2 for ENI: 0.7512284637173079
# R^2 for EON-PWGLN: 0.10904314928280878
# R^2 for EON-UK: 0.06801423643819615
# R^2 for ERGBA: -0.37901575833333245
# R^2 for ESS: -23.676749150750044
# R^2 for EVRGSA: -12.856468235801632
# R^2 for EXPGRL-EXPFIN: -194.05955427939685
# R^2 for F-FCEBank: -0.7661091309548462
# R^2 for FERRUZ: -0.21056125977037965
# R^2 for FGPLN: -1.0665486472775103
# R^2 for FINL: -18.535192094325353
# R^2 for FORTUM: -12.086615031607243
# R^2 for FRTR: -1.2344586090032053
# R^2 for FSEKGA: -7.646060326611552
# R^2 for GFCFP: -7.824101733537512
# R^2 for GLCORE: -2.069388993131781
# R^2 for GROHE: -0.2572606864963778
# R^2 for GROUPE: 0.4187533266665735
# R^2 for GSK: -302.0856302014951
# R^2 for HAMRSN: 0.6621822581885157
# R^2 for HAVAS: -1.603139073010182
# R^2 for HBOS: -0.3753085155236815
# R^2 for HBOS-ScotBkPLC: 0.4220589260930494
# R^2 for HEI: -7.905389167387964
# R^2 for HEI-HANSN: -1.6510022020970183
# R^2 for HEIANA: -3.6412979737969158
# R^2 for HEIANA-SCOT: -393.82339387591804
# R^2 for HENAGK: 0.7396431783432205
# R^2 for HESLAN: 0.4585197323573227
# R^2 for HOFP: -2.1161418064062767
# R^2 for HSBC: 0.8945784374068044
# R^2 for HSBC-HSBCBank: 0.6149101890615056
# R^2 for IBERDU: -0.8939446121840409
# R^2 for IBERDU-Intl: -0.8311616750079776
# R^2 for IBERDU-ScotPwr: -1.605791569904691
# R^2 for ICELND: -3.2816622959783652
# R^2 for IFX-HldgBV: -0.7513538685845795
# R^2 for IHOT: -15.213476438578507
# R^2 for III: -2.4650844191468124
# R^2 for IKB: -39.1968286654668
# R^2 for INTNED: 0.9078680035651918
# R^2 for INTNED-BankNV: 0.9236578372317515
# R^2 for INVSA: -16.44184457223674
# R^2 for IRELND: -1.2460641952185503
# R^2 for ISSAS-Global: -3.7561627323311164
# R^2 for ITALY: -0.08648187189660672
# R^2 for ITV: -0.5346229681664829
# R^2 for ITV-Carlton: -2.935560034217455
# R^2 for JAPTOB-GGL: -796.75908137686
# R^2 for KDSM: -27.788840030472322
# R^2 for KEL-YorkWat: -2.191397569812789
# R^2 for KEL-YorkWatfltd: -4.017108713395742
# R^2 for KINGFI: 0.512182268186384
# R^2 for KPN: -0.1632980333808478
# R^2 for KRCP-BankNV: -1.0797279899748435
# R^2 for LAFCP: -3.7037814558718942
# R^2 for LAGARD: -5.177616813425787
# R^2 for LAND-SecPlc: 0.32003718166352146
# R^2 for LAVORO: -2.483285626224902
# R^2 for LAZIO: 0.8636801779199562
# R^2 for LBTG-UPC: -12.937776832627964
# R^2 for LBW: 0.3605913765730535
# R^2 for LGEN: -0.5914619668376406
# R^2 for LGRDSA-frnc: -43.966649117693315
# R^2 for LIFP: -0.9059406903073881
# R^2 for LINDE: -41.47166119315637
# R^2 for LMETEL: 0.2592391901084865
# R^2 for LNX: 0.46404198932901264
# R^2 for LOREAL: -290.98446922772274
# R^2 for LUFTHA: -0.7992620043391878
# R^2 for MANSE: -276.75164875419205
# R^2 for METSO: 0.29370698784428273
# R^2 for MICHLN: -102.10540632863666
# R^2 for MKGA: -4.99620210391805
# R^2 for MKS: -4.5559259802417715
# R^2 for MKS-M+SPlc: -4.2877948168290425
# R^2 for MOET: -22.37137035618214
# R^2 for MONTE: -3.8557156423515995
# R^2 for MUNRE: -128.88134844536523
# R^2 for NDB: 0.2780761285961887
# R^2 for NESTLE: -111.8767290165663
# R^2 for NETHRS: -11.793718689292271
# R^2 for NGGPLC: -0.6679711258009442
# R^2 for NGP: -25.46969143672044
# R^2 for NGP-NGET: -25.1648867323734
# R^2 for NIBBNK: -6.3533625722053575
# R^2 for NIECO: -59.14161137743864
# R^2 for NIPSHG-PILKING: -0.6471907322299546
# R^2 for NOKIA: -1.0931353486826043
# R^2 for NORWAY: -109.89419362099244
# R^2 for NOVART: -0.523309072738765
# R^2 for NSINO: -5.132093758937417
# R^2 for NXP: -3.58662773951686
# R^2 for NXT: -5.925468920112215
# R^2 for OTE: -1.643272969021031
# R^2 for PAUTO: 0.5622318486487907
# R^2 for PERNOD: 0.4649620335335657
# R^2 for PEUGOT: -3.382186457784427
# R^2 for PEUGOT-BanqPsa: -0.7563851844937475
# R^2 for PIRELN: -76.62785924480168
# R^2 for PORTUG: -2.36813934551553
# R^2 for PPWRC: -3.2981331325421515
# R^2 for PREUSS: -2.4278798421844163
# R^2 for PRUFIN: -0.5032775866517802
# R^2 for PSON: -233.35401824032684
# R^2 for PUBFP: 0.0772128266200055
# R^2 for RAGAG-EVODEG: -192.25366692170962
# R^2 for RBOSCH: -242.43021596970098
# R^2 for RDMB: -9.081151968276139
# R^2 for RDNA-ShellPet: -12.774870025305734
# R^2 for RDNA-ShellPetLt: -0.22486160214953044
# R^2 for RDSPLC: -0.23992069793073556
# R^2 for RECSA: -4.307145135487922
# R^2 for RENAUL: -2.5264941275783457
# R^2 for RENAUL-RCIBanq: -2.608901004293032
# R^2 for RENTPL: -2.315082627887709
# R^2 for RHEINM-Rheinmet: -2.1489756682427474
# R^2 for RIOLN: -7.62345099128213
# R^2 for RNK: -7.940300678363823
# R^2 for RNTKIL: -2.1503553239865063
# R^2 for ROLLS: -17.325191538534423
# R^2 for ROSW: -0.5832423828276816
# R^2 for RSA-InsPLC: -8.029001336364994
# R^2 for RSAIG: -7.889982057056109
# R^2 for RXLDEV: -1.328893593471418
# R^2 for SANPAO: -1.821449266895153
# R^2 for SANTNDR: 0.9443585290913914
# R^2 for SANUK: -0.00826120954695675
# R^2 for SAPSJ-SGM: -7.940453568666506
# R^2 for SBRY: 0.050242501636463044
# R^2 for SCACAP: 0.6579319638840626
# R^2 for SCANIA: -2.150429832673795
# R^2 for SCMNVX: -9.518430169449417
# R^2 for SCORS: -0.07978189446112527
# R^2 for SCOTPO-Ukplc: -5.918656745205592
# R^2 for SEB: 0.8163503645114719
# R^2 for SECURI: -1.8206039325399872
# R^2 for SESG: -30.003946117269763
# R^2 for SGCLN: -43.464248200348216
# R^2 for SGRO: -0.35567806796410983
# R^2 for SICILY: 0.5600500769477652
# R^2 for SIEM: -15.932860368569767
# R^2 for SKF: -5275.372460860529
# R^2 for SLTRW-Kelda: -68.7024435940648
# R^2 for SMIN: -1.1698998330386075
# R^2 for SOCGEN: 0.544869611851245
# R^2 for SOLL: -7.906988185102838
# R^2 for SOLVAY: 0.7629626341621008
# R^2 for SPAIN: -1.9675235382106648
# R^2 for STAN: -0.5445050291916487
# R^2 for STAN-Bank: 0.5933416515419118
# R^2 for STB: -11.015979738194694
# R^2 for STENA: -8.063542547137713
# R^2 for STGOBN: 0.49224223083415397
# R^2 for STLIFE-LifeAss: -46.417833022264276
# R^2 for STM: 0.4745967658592023
# R^2 for STORA: 0.8790091348926633
# R^2 for SVSKHB: -1.1949774561146684
# R^2 for SWED: -24.436303905656676
# R^2 for SWEDBK: 0.6100324723103181
# R^2 for SWEMAT: -0.22772714986999287
# R^2 for SWISS: -56.11053954920392
# R^2 for SWLHLD: -17.622105261223105
# R^2 for SWREL: -5.121565576591257
# R^2 for SWSL: -0.7083973857737955
# R^2 for SXLTD: -384.0095253131356
# R^2 for SYNNVX: -31.499935795891936
# R^2 for TATAGP-CORUSLTD: -12.402750769114943
# R^2 for TATELN: -9.34117558759383
# R^2 for TELDAN: -3.0353659926899015
# R^2 for TELEFO: -1.2744932509375766
# R^2 for TELNOR: -13.659761025642185
# R^2 for TFIFP: -6.802575363367732
# R^2 for TIIMN: -4.137891692810474
# R^2 for TKA: 0.09140028168771142
# R^2 for TKAGR: -4.472006913471478
# R^2 for TMSNRP-TRGL: -317.0482963462644
# R^2 for TNET: -31.78535635345373
# R^2 for TOTALN: -12.714971322893911
# R^2 for TSCO: -65.88554459923743
# R^2 for TWPLC: -13.98058254124758
# R^2 for TYECOG: -9.555190842434941
# R^2 for UBS: 0.8311994499056865
# R^2 for UCBAG: -0.31018586360579925
# R^2 for UKIN: -13.253037783696092
# R^2 for ULVR: -84.09654572997893
# R^2 for UPMKYM: 0.8501523242771558
# R^2 for USPA: 0.24160312566467756
# R^2 for UU: -2.6539020607280213
# R^2 for VEOLIA: 0.4219779465443997
# R^2 for VINCI: 0.36433709257084645
# R^2 for VIRFIN: -8.597038074505294
# R^2 for VIVNDI: 0.4605600685327722
# R^2 for VLOF: 0.6917253063411595
# R^2 for VLVY: -0.3641445205382938
# R^2 for VLVY-Treasury: -0.20717542701276215
# R^2 for VOD: -418.8682005124666
# R^2 for VW: 0.9041484752077473
# R^2 for WEINBG: -19.254974845756323
# R^2 for WENL: 0.2967654747514554
# R^2 for WINDAQ: -3.4114853208101845
# R^2 for WOLKLU: -20.25101053986508
# R^2 for WPPGRP-2005: -11.929049307146306
# R^2 for YORPOW: -39.99959244256289
# R^2 for ZINCO: -1.2552097471154462

# %%
# Define a function to calculate R^2 for each bucket on a given date, including item counts
def calculate_r2_by_bucket(data, metadata, date, actual_col, predicted_col, bucket_cols):
    # Filter the main data for the specified date
    date_data = data[data["Date"] == date]
    
    if date_data.empty:
        raise ValueError(f"No data found for the specified date: {date}")

    # Merge the main data with metadata to get bucket information
    merged_data = date_data.merge(metadata, on="Ticker", how="inner")
    
    # Group data by the specified bucket columns
    grouped = merged_data.groupby(bucket_cols)

    # Calculate R^2 for each bucket and include the number of items
    bucket_r2_results = {}
    for bucket, group in grouped:
        actual = group[actual_col]
        predicted = group[predicted_col]
        bucket_size = len(group)  # Number of items in the bucket
        try:
            r2 = calculate_r_squared(actual, predicted)
            bucket_r2_results[bucket] = {"R^2": r2, "Count": bucket_size}
        except ZeroDivisionError:
            bucket_r2_results[bucket] = {"R^2": None, "Count": bucket_size}  # Handle cases with no variance in actual values

    return bucket_r2_results

metadata = pd.read_csv('data/metadata.csv') 
bucket_cols = ["Sector", "Country", "AverageRating"]  # Define the bucket columns
actual_col = "Actual_Spread"
predicted_col = "Proxy_CSRA"  
date = "2010-09-14" 


r2_results_by_bucket = calculate_r2_by_bucket(
    data=proxy_time_series_df_alex,
    metadata=metadata,
    date=date,
    actual_col=actual_col,
    predicted_col=predicted_col,
    bucket_cols=bucket_cols
)
for bucket, results in r2_results_by_bucket.items():
    r2 = results["R^2"]
    count = results["Count"]
    print(f"Bucket {bucket}: R^2 = {r2}, Count = {count}")
# Out:
# Bucket ('Basic Materials', 'Austria', 12): R^2 = -inf, Count = 1
# Bucket ('Basic Materials', 'Belgium', 9): R^2 = -inf, Count = 1
# Bucket ('Basic Materials', 'Finland', 10): R^2 = -510.4894363942954, Count = 2
# Bucket ('Basic Materials', 'France', 10): R^2 = -inf, Count = 1
# Bucket ('Basic Materials', 'France', 17): R^2 = -inf, Count = 1
# Bucket ('Basic Materials', 'Germany', 6): R^2 = -1121.199297212437, Count = 2
# Bucket ('Basic Materials', 'Germany', 10): R^2 = -inf, Count = 1
# Bucket ('Basic Materials', 'Germany', 14): R^2 = -inf, Count = 1
# Bucket ('Basic Materials', 'Germany', 17): R^2 = -inf, Count = 1
# Bucket ('Basic Materials', 'Luxembourg', 9): R^2 = 0.7024238652592537, Count = 2
# Bucket ('Basic Materials', 'Luxembourg', 18): R^2 = -inf, Count = 1
# Bucket ('Basic Materials', 'Netherlands', 9): R^2 = -inf, Count = 1
# Bucket ('Basic Materials', 'Netherlands', 10): R^2 = -inf, Count = 1
# Bucket ('Basic Materials', 'Norway', 18): R^2 = -inf, Count = 1
# Bucket ('Basic Materials', 'Switzerland', 7): R^2 = -inf, Count = 1
# Bucket ('Basic Materials', 'Switzerland', 10): R^2 = -0.1989082347353368, Count = 3
# Bucket ('Basic Materials', 'United Kingdom', 10): R^2 = -13.612451175219947, Count = 2
# Bucket ('Basic Materials', 'United Kingdom', 14): R^2 = -inf, Count = 1
# Bucket ('Basic Materials', 'United Kingdom', 17): R^2 = -0.15130206264835722, Count = 2
# Bucket ('Consumer Goods', 'Denmark', 1): R^2 = -inf, Count = 1
# Bucket ('Consumer Goods', 'Denmark', 10): R^2 = -inf, Count = 1
# Bucket ('Consumer Goods', 'France', 3): R^2 = -inf, Count = 1
# Bucket ('Consumer Goods', 'France', 4): R^2 = -inf, Count = 1
# Bucket ('Consumer Goods', 'France', 8): R^2 = -inf, Count = 1
# Bucket ('Consumer Goods', 'France', 10): R^2 = -1.1802909200816019, Count = 3
# Bucket ('Consumer Goods', 'France', 11): R^2 = -inf, Count = 1
# Bucket ('Consumer Goods', 'France', 14): R^2 = -1.2777561252982776, Count = 2
# Bucket ('Consumer Goods', 'Germany', 6): R^2 = -205.1107768969345, Count = 2
# Bucket ('Consumer Goods', 'Germany', 7): R^2 = -inf, Count = 1
# Bucket ('Consumer Goods', 'Germany', 8): R^2 = -inf, Count = 1
# Bucket ('Consumer Goods', 'Germany', 10): R^2 = -0.0699545058649853, Count = 4
# Bucket ('Consumer Goods', 'Italy', 9): R^2 = -inf, Count = 1
# Bucket ('Consumer Goods', 'Netherlands', 7): R^2 = -inf, Count = 1
# Bucket ('Consumer Goods', 'Netherlands', 17): R^2 = -inf, Count = 1
# Bucket ('Consumer Goods', 'Spain', 10): R^2 = -inf, Count = 1
# Bucket ('Consumer Goods', 'Sweden', 17): R^2 = -89.58119918655714, Count = 3
# Bucket ('Consumer Goods', 'Switzerland', 4): R^2 = -inf, Count = 1
# Bucket ('Consumer Goods', 'United Kingdom', 10): R^2 = -0.05414197721917269, Count = 5
# Bucket ('Consumer Goods', 'United Kingdom', 14): R^2 = -inf, Count = 1
# Bucket ('Consumer Goods', 'United Kingdom', 17): R^2 = -inf, Count = 1
# Bucket ('Consumer Services', 'Belgium', 13): R^2 = -inf, Count = 1
# Bucket ('Consumer Services', 'France', 7): R^2 = -inf, Count = 1
# Bucket ('Consumer Services', 'France', 9): R^2 = -164.07548221747467, Count = 2
# Bucket ('Consumer Services', 'France', 10): R^2 = -0.11662240256257284, Count = 4
# Bucket ('Consumer Services', 'France', 15): R^2 = -inf, Count = 1
# Bucket ('Consumer Services', 'France', 17): R^2 = -inf, Count = 1
# Bucket ('Consumer Services', 'France', 22): R^2 = -inf, Count = 1
# Bucket ('Consumer Services', 'Germany', 2): R^2 = -inf, Count = 1
# Bucket ('Consumer Services', 'Germany', 10): R^2 = -inf, Count = 1
# Bucket ('Consumer Services', 'Germany', 11): R^2 = -inf, Count = 1
# Bucket ('Consumer Services', 'Netherlands', 9): R^2 = -inf, Count = 1
# Bucket ('Consumer Services', 'Netherlands', 10): R^2 = -0.34726173188595966, Count = 2
# Bucket ('Consumer Services', 'United Kingdom', 7): R^2 = -inf, Count = 1
# Bucket ('Consumer Services', 'United Kingdom', 8): R^2 = -inf, Count = 1
# Bucket ('Consumer Services', 'United Kingdom', 9): R^2 = -inf, Count = 1
# Bucket ('Consumer Services', 'United Kingdom', 10): R^2 = -4.1748334737098185, Count = 12
# Bucket ('Consumer Services', 'United Kingdom', 17): R^2 = -0.046763250778314, Count = 10
# Bucket ('Financials', 'Austria', 6): R^2 = -inf, Count = 1
# Bucket ('Financials', 'Austria', 10): R^2 = -inf, Count = 1
# Bucket ('Financials', 'Belgium', 6): R^2 = -inf, Count = 1
# Bucket ('Financials', 'Belgium', 10): R^2 = -inf, Count = 1
# Bucket ('Financials', 'Denmark', 6): R^2 = -inf, Count = 1
# Bucket ('Financials', 'Denmark', 10): R^2 = -inf, Count = 1
# Bucket ('Financials', 'France', 5): R^2 = -25.036242120488964, Count = 3
# Bucket ('Financials', 'France', 6): R^2 = -0.07355846238665875, Count = 4
# Bucket ('Financials', 'France', 10): R^2 = -1.18788480060319, Count = 6
# Bucket ('Financials', 'Germany', 3): R^2 = -inf, Count = 1
# Bucket ('Financials', 'Germany', 5): R^2 = -inf, Count = 1
# Bucket ('Financials', 'Germany', 7): R^2 = -75.48409993137673, Count = 2
# Bucket ('Financials', 'Germany', 10): R^2 = -0.4198223192795305, Count = 7
# Bucket ('Financials', 'Germany', 19): R^2 = -inf, Count = 1
# Bucket ('Financials', 'Greece', 10): R^2 = -inf, Count = 1
# Bucket ('Financials', 'Ireland', 10): R^2 = -5.646961788313539, Count = 2
# Bucket ('Financials', 'Italy', 9): R^2 = -inf, Count = 1
# Bucket ('Financials', 'Italy', 10): R^2 = -6.612935528371925, Count = 4
# Bucket ('Financials', 'Italy', 13): R^2 = -inf, Count = 1
# Bucket ('Financials', 'Luxembourg', 17): R^2 = -inf, Count = 1
# Bucket ('Financials', 'Netherlands', 5): R^2 = -2677.388582553656, Count = 3
# Bucket ('Financials', 'Netherlands', 10): R^2 = -41.73861013898434, Count = 3
# Bucket ('Financials', 'Norway', 10): R^2 = -inf, Count = 1
# Bucket ('Financials', 'Portugal', 8): R^2 = -295.6352590709639, Count = 2
# Bucket ('Financials', 'Portugal', 10): R^2 = -inf, Count = 1
# Bucket ('Financials', 'Spain', 7): R^2 = -202.43017302820533, Count = 2
# Bucket ('Financials', 'Spain', 8): R^2 = -inf, Count = 1
# Bucket ('Financials', 'Spain', 10): R^2 = -6.956820811788047, Count = 2
# Bucket ('Financials', 'Sweden', 5): R^2 = -75.9146197210699, Count = 3
# Bucket ('Financials', 'Sweden', 17): R^2 = -inf, Count = 1
# Bucket ('Financials', 'Switzerland', 1): R^2 = -inf, Count = 1
# Bucket ('Financials', 'Switzerland', 5): R^2 = -inf, Count = 1
# Bucket ('Financials', 'Switzerland', 10): R^2 = -2.138768926987462, Count = 4
# Bucket ('Financials', 'United Kingdom', 1): R^2 = -inf, Count = 1
# Bucket ('Financials', 'United Kingdom', 5): R^2 = -284.8392274043642, Count = 3
# Bucket ('Financials', 'United Kingdom', 6): R^2 = -9.576106028079707, Count = 4
# Bucket ('Financials', 'United Kingdom', 7): R^2 = -383.41430490272273, Count = 3
# Bucket ('Financials', 'United Kingdom', 9): R^2 = -inf, Count = 1
# Bucket ('Financials', 'United Kingdom', 10): R^2 = -0.1145086420468655, Count = 8
# Bucket ('Financials', 'United Kingdom', 17): R^2 = -6.014191303001277, Count = 2
# Bucket ('Government', 'Austria', 10): R^2 = -inf, Count = 1
# Bucket ('Government', 'Belgium', 13): R^2 = -inf, Count = 1
# Bucket ('Government', 'Cyprus', 10): R^2 = -inf, Count = 1
# Bucket ('Government', 'Denmark', 10): R^2 = -inf, Count = 1
# Bucket ('Government', 'Finland', 10): R^2 = -inf, Count = 1
# Bucket ('Government', 'France', 10): R^2 = -inf, Count = 1
# Bucket ('Government', 'Germany', 10): R^2 = -inf, Count = 1
# Bucket ('Government', 'Iceland', 10): R^2 = -inf, Count = 1
# Bucket ('Government', 'Ireland', 10): R^2 = -inf, Count = 1
# Bucket ('Government', 'Italy', 10): R^2 = -9.724004227629566, Count = 3
# Bucket ('Government', 'Netherlands', 9): R^2 = -inf, Count = 1
# Bucket ('Government', 'Netherlands', 10): R^2 = -inf, Count = 1
# Bucket ('Government', 'Norway', 10): R^2 = -inf, Count = 1
# Bucket ('Government', 'Portugal', 10): R^2 = -inf, Count = 1
# Bucket ('Government', 'Spain', 10): R^2 = -inf, Count = 1
# Bucket ('Government', 'Sweden', 10): R^2 = -inf, Count = 1
# Bucket ('Government', 'Switzerland', 10): R^2 = -inf, Count = 1
# Bucket ('Government', 'United Kingdom', 10): R^2 = -inf, Count = 1
# Bucket ('Health Care', 'Germany', 7): R^2 = -0.4276696818316119, Count = 2
# Bucket ('Health Care', 'Germany', 10): R^2 = -inf, Count = 1
# Bucket ('Health Care', 'Switzerland', 10): R^2 = -372.4567977179001, Count = 2
# Bucket ('Health Care', 'United Kingdom', 7): R^2 = -inf, Count = 1
# Bucket ('Health Care', 'United Kingdom', 17): R^2 = -inf, Count = 1
# Bucket ('Industrials', 'Austria', 9): R^2 = -inf, Count = 1
# Bucket ('Industrials', 'Finland', 10): R^2 = -inf, Count = 1
# Bucket ('Industrials', 'France', 8): R^2 = -inf, Count = 1
# Bucket ('Industrials', 'France', 9): R^2 = -inf, Count = 1
# Bucket ('Industrials', 'France', 10): R^2 = -0.067553308133246, Count = 5
# Bucket ('Industrials', 'France', 14): R^2 = -inf, Count = 1
# Bucket ('Industrials', 'France', 17): R^2 = -inf, Count = 1
# Bucket ('Industrials', 'Germany', 6): R^2 = -inf, Count = 1
# Bucket ('Industrials', 'Germany', 10): R^2 = -3.4562289249029003, Count = 2
# Bucket ('Industrials', 'Germany', 14): R^2 = -0.09957875062741084, Count = 2
# Bucket ('Industrials', 'Germany', 17): R^2 = -inf, Count = 1
# Bucket ('Industrials', 'Italy', 10): R^2 = -inf, Count = 1
# Bucket ('Industrials', 'Luxembourg', 10): R^2 = -inf, Count = 1
# Bucket ('Industrials', 'Portugal', 17): R^2 = -inf, Count = 1
# Bucket ('Industrials', 'Spain', 9): R^2 = -inf, Count = 1
# Bucket ('Industrials', 'Sweden', 7): R^2 = -5.049189513939253, Count = 3
# Bucket ('Industrials', 'Sweden', 8): R^2 = -inf, Count = 1
# Bucket ('Industrials', 'Sweden', 9): R^2 = -inf, Count = 1
# Bucket ('Industrials', 'Sweden', 10): R^2 = -0.7517683149622971, Count = 2
# Bucket ('Industrials', 'Sweden', 14): R^2 = -inf, Count = 1
# Bucket ('Industrials', 'United Kingdom', 7): R^2 = -inf, Count = 1
# Bucket ('Industrials', 'United Kingdom', 9): R^2 = -inf, Count = 1
# Bucket ('Industrials', 'United Kingdom', 10): R^2 = -2.6563691238359506, Count = 5
# Bucket ('Industrials', 'United Kingdom', 17): R^2 = -inf, Count = 1
# Bucket ('Oil & Gas', 'France', 10): R^2 = -inf, Count = 1
# Bucket ('Oil & Gas', 'Italy', 10): R^2 = -inf, Count = 1
# Bucket ('Oil & Gas', 'Netherlands', 10): R^2 = -inf, Count = 1
# Bucket ('Oil & Gas', 'Spain', 10): R^2 = -inf, Count = 1
# Bucket ('Oil & Gas', 'United Kingdom', 10): R^2 = -0.31212276079855994, Count = 3
# Bucket ('Technology', 'Finland', 14): R^2 = -inf, Count = 1
# Bucket ('Technology', 'France', 10): R^2 = -inf, Count = 1
# Bucket ('Technology', 'Germany', 10): R^2 = -inf, Count = 1
# Bucket ('Technology', 'Netherlands', 1): R^2 = -inf, Count = 1
# Bucket ('Technology', 'Netherlands', 10): R^2 = -inf, Count = 1
# Bucket ('Technology', 'Sweden', 10): R^2 = -inf, Count = 1
# Bucket ('Telecommunications', 'Austria', 14): R^2 = -inf, Count = 1
# Bucket ('Telecommunications', 'Denmark', 17): R^2 = -inf, Count = 1
# Bucket ('Telecommunications', 'Finland', 10): R^2 = -inf, Count = 1
# Bucket ('Telecommunications', 'France', 9): R^2 = -inf, Count = 1
# Bucket ('Telecommunications', 'Germany', 6): R^2 = -inf, Count = 1
# Bucket ('Telecommunications', 'Greece', 10): R^2 = -inf, Count = 1
# Bucket ('Telecommunications', 'Italy', 12): R^2 = -inf, Count = 1
# Bucket ('Telecommunications', 'Luxembourg', 10): R^2 = -inf, Count = 1
# Bucket ('Telecommunications', 'Netherlands', 8): R^2 = -inf, Count = 1
# Bucket ('Telecommunications', 'Norway', 7): R^2 = -inf, Count = 1
# Bucket ('Telecommunications', 'Spain', 17): R^2 = -inf, Count = 1
# Bucket ('Telecommunications', 'Switzerland', 6): R^2 = -inf, Count = 1
# Bucket ('Telecommunications', 'United Kingdom', 1): R^2 = -inf, Count = 1
# Bucket ('Telecommunications', 'United Kingdom', 10): R^2 = -0.3260739877791661, Count = 3
# Bucket ('Telecommunications', 'United Kingdom', 13): R^2 = -inf, Count = 1
# Bucket ('Utilities', 'Belgium', 7): R^2 = -inf, Count = 1
# Bucket ('Utilities', 'Belgium', 10): R^2 = -inf, Count = 1
# Bucket ('Utilities', 'Finland', 9): R^2 = -inf, Count = 1
# Bucket ('Utilities', 'France', 4): R^2 = -inf, Count = 1
# Bucket ('Utilities', 'France', 7): R^2 = -inf, Count = 1
# Bucket ('Utilities', 'Germany', 7): R^2 = -inf, Count = 1
# Bucket ('Utilities', 'Greece', 10): R^2 = -inf, Count = 1
# Bucket ('Utilities', 'Italy', 10): R^2 = -1.104123561344637, Count = 3
# Bucket ('Utilities', 'Italy', 17): R^2 = -inf, Count = 1
# Bucket ('Utilities', 'Netherlands', 3): R^2 = -inf, Count = 1
# Bucket ('Utilities', 'Netherlands', 10): R^2 = -8.58899181628371, Count = 3
# Bucket ('Utilities', 'Portugal', 10): R^2 = -inf, Count = 1
# Bucket ('Utilities', 'Spain', 6): R^2 = -inf, Count = 1
# Bucket ('Utilities', 'Spain', 8): R^2 = -inf, Count = 1
# Bucket ('Utilities', 'Spain', 10): R^2 = -1.1830636785300679, Count = 2
# Bucket ('Utilities', 'United Kingdom', 1): R^2 = -inf, Count = 1
# Bucket ('Utilities', 'United Kingdom', 7): R^2 = -inf, Count = 1
# Bucket ('Utilities', 'United Kingdom', 8): R^2 = -inf, Count = 1
# Bucket ('Utilities', 'United Kingdom', 9): R^2 = -inf, Count = 1
# Bucket ('Utilities', 'United Kingdom', 10): R^2 = -44.28080179800413, Count = 8
# Bucket ('Utilities', 'United Kingdom', 17): R^2 = -0.41964629096144557, Count = 2
# C:\Users\iChin\AppData\Local\Temp\ipykernel_22728\4173699830.py:8: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - (ssr / tss)
